# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import classification_report
import pickle
import numpy as np

# %%
with open("h0_kernel_train.pkl", "rb") as f:
    h0_kernel_train = pickle.load(f)
with open("h0_kernel_test.pkl", "rb") as f:
    h0_kernel_test = pickle.load(f)
with open("h1_kernel_train.pkl", "rb") as f:
    h1_kernel_train = pickle.load(f)
with open("h1_kernel_test.pkl", "rb") as f:
    h1_kernel_test = pickle.load(f)
with open("h0_complete_kernel_train.pkl", "rb") as f:
    h0_complete_kernel_train = pickle.load(f)
with open("h0_complete_kernel_test.pkl", "rb") as f:
    h0_complete_kernel_test = pickle.load(f)
with open("train_y.pkl", "rb") as f:
    y_train = pickle.load(f)
with open("test_y.pkl", "rb") as f:
    y_test = pickle.load(f)
with open("train_h0sr.pkl", "rb") as f:
    train_h0sr = pickle.load(f)
with open("test_h0sr.pkl", "rb") as f:
    test_h0sr = pickle.load(f)
with open("train_h1sr.pkl", "rb") as f:
    train_h1sr = pickle.load(f)
with open("test_h1sr.pkl", "rb") as f:
    test_h1sr = pickle.load(f)
with open("train_h0sr_complete.pkl", "rb") as f:
    train_h0sr_complete = pickle.load(f)
with open("test_h0sr_complete.pkl", "rb") as f:
    test_h0sr_complete = pickle.load(f)
with open("X_train.pkl", "rb") as f:
    X_train = pickle.load(f)
with open("X_test.pkl", "rb") as f:
    X_test = pickle.load(f)

# %%
print(np.max(h0_kernel_train))
print(np.max(h1_kernel_train))
print(np.max(h0_complete_kernel_train))
# Out:
# 112344.04904499945
# 302.36971941189574
# 120967940.45243345

# %%
scale_h0 = 1
scale_h1 = 1
scale_h0_complete = 100000

print(scale_h0)
print(scale_h1)
print(scale_h0_complete)
# Out:
# 1
# 1
# 100000

# %% [markdown]
# # H0 complete (clustering) stable rank

# %%
# Fit SVC on the precomputed train kernel

# VALID KERNEL TRANSFORMATION for stability
h0_complete_kernel_train_scaled = h0_complete_kernel_train / scale_h0_complete 
h0_complete_kernel_test_scaled = h0_complete_kernel_test / scale_h0_complete

svc = SVC(kernel='precomputed')
svc.fit(h0_complete_kernel_train_scaled, y_train)
# Predict using the precomputed test kernel
y_pred = svc.predict(h0_complete_kernel_test_scaled)
# Classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79       200
#            1       0.79      0.78      0.79       200
#
#     accuracy                           0.79       400
#    macro avg       0.79      0.79      0.79       400
# weighted avg       0.79      0.79      0.79       400

# %% [markdown]
# # H0 stable rank

# %%
svc = SVC(kernel='precomputed')

h0_kernel_train_scaled = h0_kernel_train / scale_h0
h0_kernel_test_scaled = h0_kernel_test / scale_h0

svc.fit(h0_kernel_train_scaled, y_train)
# Predict using the precomputed test kernel
y_pred = svc.predict(h0_kernel_test_scaled)
# Classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.81      0.75       200
#            1       0.77      0.65      0.70       200
#
#     accuracy                           0.72       400
#    macro avg       0.73      0.73      0.72       400
# weighted avg       0.73      0.72      0.72       400

# %% [markdown]
# # H1 stable rank

# %%
h1_kernel_train_scaled = h1_kernel_train / scale_h1
h1_kernel_test_scaled = h1_kernel_test / scale_h1
svc = SVC(kernel='precomputed')
svc.fit(h1_kernel_train_scaled, y_train)
# Predict using the precomputed test kernel
y_pred = svc.predict(h1_kernel_test_scaled)
# Classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.74      0.75       200
#            1       0.75      0.75      0.75       200
#
#     accuracy                           0.75       400
#    macro avg       0.75      0.75      0.75       400
# weighted avg       0.75      0.75      0.75       400

# %% [markdown]
# # Triple Composite Kernel

# %%
composite_kernel_train = h0_complete_kernel_train_scaled + h1_kernel_train_scaled + h0_kernel_train_scaled
composite_kernel_test = h0_complete_kernel_test_scaled + h1_kernel_test_scaled + h0_kernel_test_scaled


# Fit SVC on the precomputed train kernel
svc = SVC(kernel='precomputed')
svc.fit(composite_kernel_train, y_train)
# Predict using the precomputed test kernel
y_pred = svc.predict(composite_kernel_test)
# Classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.80       200
#            1       0.79      0.84      0.82       200
#
#     accuracy                           0.81       400
#    macro avg       0.81      0.81      0.81       400
# weighted avg       0.81      0.81      0.81       400

# %% [markdown]
# # Baseline

# %%
# LINEAR KERNEL (NON OPTIMIZED BASELINE)

X_train_data = np.asarray([np.asarray(X.flatten()) for X in X_train], dtype=np.float32) # 10000x257
X_test_data = np.asarray([np.asarray(X.flatten()) for X in X_test], dtype=np.float32) # 10000x257

baseline_train_kernel = X_train_data @ X_train_data.T
baseline_test_kernel = X_test_data @ X_train_data.T

# %%
# Fit SVC on the precomputed train kernel
svc = SVC(kernel='precomputed')
svc.fit(baseline_train_kernel, y_train)
# Predict using the precomputed test kernel
y_pred = svc.predict(baseline_test_kernel)
# Classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78       200
#            1       0.80      0.70      0.75       200
#
#     accuracy                           0.76       400
#    macro avg       0.77      0.76      0.76       400
# weighted avg       0.77      0.76      0.76       400

# %%
K1 = h0_complete_kernel_train_scaled
K2 = 1000*h1_kernel_train_scaled
K3 = h0_kernel_train_scaled
y = y_train
y_test = y_test
K1_test = h0_complete_kernel_test_scaled
K2_test = 1000*h1_kernel_test_scaled
K3_test = h0_kernel_test_scaled

# %%
# Cross-validate (w1,w2,w3,C) for a precomputed-kernel SVM, then evaluate on test kernels.
# You must already have:
#   K1, K2, K3                 : (n_train, n_train) numpy arrays
#   K1_test, K2_test, K3_test  : (n_test, n_train) numpy arrays
#   y                          : (n_train,) labels
#   y_test                     : (n_test,) labels

import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

class MultiKernelSVC(BaseEstimator, ClassifierMixin):
    def __init__(self, K1, K2, K3, weights=(1.0, 0.0, 0.0), C=1.0, normalize_weights=True, random_state=0):
        self.K1 = K1
        self.K2 = K2
        self.K3 = K3
        self.weights = weights
        self.C = C
        self.normalize_weights = normalize_weights
        self.random_state = random_state

    def _norm_weights(self, w):
        w = np.asarray(w, float)
        if self.normalize_weights:
            s = w.sum()
            if s > 0:
                w = w / s
        return w

    def _combine(self, rows, cols, w):
        return (w[0] * self.K1[np.ix_(rows, cols)]
              + w[1] * self.K2[np.ix_(rows, cols)]
              + w[2] * self.K3[np.ix_(rows, cols)])

    def fit(self, X, y):
        idx = np.asarray(X, int).ravel()
        w = self._norm_weights(self.weights)
        K = self._combine(idx, idx, w)
        self._svc = SVC(C=self.C, kernel='precomputed', random_state=self.random_state)
        self._svc.fit(K, y)
        self.train_idx_ = idx
        self.weights_ = w
        return self

    def predict(self, X):
        idx = np.asarray(X, int).ravel()
        K = self._combine(idx, self.train_idx_, self.weights_)
        return self._svc.predict(K)

    def decision_function(self, X):
        idx = np.asarray(X, int).ravel()
        K = self._combine(idx, self.train_idx_, self.weights_)
        return self._svc.decision_function(K)

    def predict_from_test_kernels(self, K1_test, K2_test, K3_test):
        w = self.weights_
        K = w[0]*K1_test + w[1]*K2_test + w[2]*K3_test
        return self._svc.predict(K)

# ---- CV setup ----
n = K1.shape[0]
indices = np.arange(n)

# convex weights grid (sum to 1)
STEP = 0.25
grid_weights = []
vals = np.arange(0.0, 1.0 + 1e-12, STEP)
for a in vals:
    for b in vals:
        c = 1.0 - a - b
        if -1e-9 <= c <= 1.0 + 1e-9:
            c = float(max(0.0, min(1.0, c)))
            if abs((a + b + c) - 1.0) <= 1e-9:
                grid_weights.append((float(a), float(b), float(c)))

param_grid = {
    "weights": grid_weights,
    "C": [0.1, 0.5, 1.0],
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
est = MultiKernelSVC(K1=K1, K2=K2, K3=K3, normalize_weights=True, random_state=0)

gs = GridSearchCV(
    estimator=est,
    param_grid=param_grid,
    cv=cv,
    scoring="accuracy",
    n_jobs=-1,
    refit=True,
    verbose=10,   # <- set high verbosity
)

# ---- Fit & select ----
gs.fit(indices, y)
print("Best params:", gs.best_params_)
print("Best CV accuracy: %.4f" % gs.best_score_)

# ---- Test evaluation ----
best_model = gs.best_estimator_
y_test_pred = best_model.predict_from_test_kernels(K1_test, K2_test, K3_test)

print("\nTest accuracy: %.4f" % accuracy_score(y_test, y_test_pred))
print("\nClassification report:\n")
print(classification_report(y_test, y_test_pred))
print("Confusion matrix:")
print(confusion_matrix(y_test, y_test_pred))
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [CV 1/5; 1/45] START C=0.1, weights=(0.0, 0.0, 1.0).............................
# [CV 2/5; 1/45] START C=0.1, weights=(0.0, 0.0, 1.0).............................
# [CV 1/5; 2/45] START C=0.1, weights=(0.0, 0.25, 0.75)...........................
# [CV 5/5; 1/45] START C=0.1, weights=(0.0, 0.0, 1.0).............................
# [CV 3/5; 1/45] START C=0.1, weights=(0.0, 0.0, 1.0).............................
# [CV 3/5; 2/45] START C=0.1, weights=(0.0, 0.25, 0.75)...........................
# [CV 2/5; 2/45] START C=0.1, weights=(0.0, 0.25, 0.75)...........................
# [CV 5/5; 1/45] END C=0.1, weights=(0.0, 0.0, 1.0);, score=0.704 total time=   0.5s
# [CV 4/5; 1/45] START C=0.1, weights=(0.0, 0.0, 1.0).............................
# [CV 1/5; 2/45] END C=0.1, weights=(0.0, 0.25, 0.75);, score=0.783 total time=   0.6s
# [CV 4/5; 2/45] START C=0.1, weights=(0.0, 0.25, 0.75)...........................
# [CV 5/5; 2/45] START C=0.1, weights=(0.0, 0.25, 0.75)...........................
# [CV 2/5; 2/45] END C=0.1, weights=(0.0, 0.25, 0.75);, score=0.775 total time=   0.7s
# [CV 3/5; 1/45] END C=0.1, weights=(0.0, 0.0, 1.0);, score=0.688 total time=   1.0s
# [CV 1/5; 3/45] START C=0.1, weights=(0.0, 0.5, 0.5).............................
# [CV 3/5; 2/45] END C=0.1, weights=(0.0, 0.25, 0.75);, score=0.750 total time=   0.8s
# [CV 2/5; 3/45] START C=0.1, weights=(0.0, 0.5, 0.5).............................
# [CV 3/5; 3/45] START C=0.1, weights=(0.0, 0.5, 0.5).............................
# [CV 2/5; 1/45] END C=0.1, weights=(0.0, 0.0, 1.0);, score=0.721 total time=   1.5s
# [CV 4/5; 3/45] START C=0.1, weights=(0.0, 0.5, 0.5).............................
# [CV 5/5; 2/45] END C=0.1, weights=(0.0, 0.25, 0.75);, score=0.692 total time=   0.7s
# [CV 5/5; 3/45] START C=0.1, weights=(0.0, 0.5, 0.5).............................
# [CV 1/5; 1/45] END C=0.1, weights=(0.0, 0.0, 1.0);, score=0.771 total time=   1.6s
# [CV 4/5; 1/45] END C=0.1, weights=(0.0, 0.0, 1.0);, score=0.750 total time=   1.0s
# [CV 1/5; 4/45] START C=0.1, weights=(0.0, 0.75, 0.25)...........................
# [CV 2/5; 4/45] START C=0.1, weights=(0.0, 0.75, 0.25)...........................
# [CV 4/5; 2/45] END C=0.1, weights=(0.0, 0.25, 0.75);, score=0.758 total time=   1.1s
# [CV 3/5; 4/45] START C=0.1, weights=(0.0, 0.75, 0.25)...........................
# [CV 1/5; 3/45] END C=0.1, weights=(0.0, 0.5, 0.5);, score=0.792 total time=   0.9s
# [CV 4/5; 4/45] START C=0.1, weights=(0.0, 0.75, 0.25)...........................
# [CV 2/5; 3/45] END C=0.1, weights=(0.0, 0.5, 0.5);, score=0.779 total time=   1.0s
# [CV 5/5; 4/45] START C=0.1, weights=(0.0, 0.75, 0.25)...........................
# [CV 4/5; 3/45] END C=0.1, weights=(0.0, 0.5, 0.5);, score=0.758 total time=   0.9s
# [CV 1/5; 5/45] START C=0.1, weights=(0.0, 1.0, 0.0).............................
# [CV 3/5; 3/45] END C=0.1, weights=(0.0, 0.5, 0.5);, score=0.742 total time=   1.3s
# [CV 2/5; 5/45] START C=0.1, weights=(0.0, 1.0, 0.0).............................
# [CV 5/5; 3/45] END C=0.1, weights=(0.0, 0.5, 0.5);, score=0.692 total time=   1.2s
# [CV 3/5; 5/45] START C=0.1, weights=(0.0, 1.0, 0.0).............................
# [CV 2/5; 4/45] END C=0.1, weights=(0.0, 0.75, 0.25);, score=0.783 total time=   1.0s
# [CV 4/5; 5/45] START C=0.1, weights=(0.0, 1.0, 0.0).............................
# [CV 3/5; 4/45] END C=0.1, weights=(0.0, 0.75, 0.25);, score=0.746 total time=   1.1s
# [CV 5/5; 5/45] START C=0.1, weights=(0.0, 1.0, 0.0).............................
# [CV 1/5; 4/45] END C=0.1, weights=(0.0, 0.75, 0.25);, score=0.792 total time=   1.4s
# [CV 1/5; 6/45] START C=0.1, weights=(0.25, 0.0, 0.75)...........................
# [CV 4/5; 4/45] END C=0.1, weights=(0.0, 0.75, 0.25);, score=0.762 total time=   1.2s
# [CV 2/5; 6/45] START C=0.1, weights=(0.25, 0.0, 0.75)...........................
# [CV 1/5; 6/45] END C=0.1, weights=(0.25, 0.0, 0.75);, score=0.833 total time=   0.2s
# [CV 3/5; 6/45] START C=0.1, weights=(0.25, 0.0, 0.75)...........................
# [CV 5/5; 4/45] END C=0.1, weights=(0.0, 0.75, 0.25);, score=0.700 total time=   1.2s
# [CV 4/5; 6/45] START C=0.1, weights=(0.25, 0.0, 0.75)...........................
# [CV 2/5; 5/45] END C=0.1, weights=(0.0, 1.0, 0.0);, score=0.779 total time=   0.9s
# [CV 5/5; 6/45] START C=0.1, weights=(0.25, 0.0, 0.75)...........................
# [CV 2/5; 6/45] END C=0.1, weights=(0.25, 0.0, 0.75);, score=0.771 total time=   0.5s
# [CV 3/5; 6/45] END C=0.1, weights=(0.25, 0.0, 0.75);, score=0.796 total time=   0.4s
# [CV 3/5; 5/45] END C=0.1, weights=(0.0, 1.0, 0.0);, score=0.688 total time=   1.1s
# [CV 1/5; 7/45] START C=0.1, weights=(0.25, 0.25, 0.5)...........................
# [CV 4/5; 6/45] END C=0.1, weights=(0.25, 0.0, 0.75);, score=0.775 total time=   0.4s
# [CV 2/5; 7/45] START C=0.1, weights=(0.25, 0.25, 0.5)...........................
# [CV 4/5; 5/45] END C=0.1, weights=(0.0, 1.0, 0.0);, score=0.729 total time=   1.0s
# [CV 5/5; 6/45] END C=0.1, weights=(0.25, 0.0, 0.75);, score=0.746 total time=   0.3s
# [CV 3/5; 7/45] START C=0.1, weights=(0.25, 0.25, 0.5)...........................
# [CV 1/5; 5/45] END C=0.1, weights=(0.0, 1.0, 0.0);, score=0.775 total time=   1.5s
# [CV 4/5; 7/45] START C=0.1, weights=(0.25, 0.25, 0.5)...........................
# [CV 5/5; 7/45] START C=0.1, weights=(0.25, 0.25, 0.5)...........................
# [CV 1/5; 8/45] START C=0.1, weights=(0.25, 0.5, 0.25)...........................
# [CV 2/5; 8/45] START C=0.1, weights=(0.25, 0.5, 0.25)...........................
# [CV 5/5; 5/45] END C=0.1, weights=(0.0, 1.0, 0.0);, score=0.713 total time=   1.2s
# [CV 3/5; 8/45] START C=0.1, weights=(0.25, 0.5, 0.25)...........................
# [CV 4/5; 7/45] END C=0.1, weights=(0.25, 0.25, 0.5);, score=0.783 total time=   0.4s
# [CV 4/5; 8/45] START C=0.1, weights=(0.25, 0.5, 0.25)...........................
# [CV 1/5; 7/45] END C=0.1, weights=(0.25, 0.25, 0.5);, score=0.829 total time=   0.5s
# [CV 5/5; 8/45] START C=0.1, weights=(0.25, 0.5, 0.25)...........................
# [CV 2/5; 7/45] END C=0.1, weights=(0.25, 0.25, 0.5);, score=0.750 total time=   0.5s
# [CV 1/5; 9/45] START C=0.1, weights=(0.25, 0.75, 0.0)...........................
# [CV 3/5; 7/45] END C=0.1, weights=(0.25, 0.25, 0.5);, score=0.779 total time=   0.5s
# [CV 5/5; 7/45] END C=0.1, weights=(0.25, 0.25, 0.5);, score=0.754 total time=   0.4s
# [CV 3/5; 9/45] START C=0.1, weights=(0.25, 0.75, 0.0)...........................
# [CV 2/5; 9/45] START C=0.1, weights=(0.25, 0.75, 0.0)...........................
# [CV 1/5; 8/45] END C=0.1, weights=(0.25, 0.5, 0.25);, score=0.821 total time=   1.0s
# [CV 2/5; 8/45] END C=0.1, weights=(0.25, 0.5, 0.25);, score=0.758 total time=   0.9s
# [CV 4/5; 9/45] START C=0.1, weights=(0.25, 0.75, 0.0)...........................
# [CV 4/5; 8/45] END C=0.1, weights=(0.25, 0.5, 0.25);, score=0.783 total time=   0.7s
# [CV 5/5; 9/45] START C=0.1, weights=(0.25, 0.75, 0.0)...........................
# [CV 1/5; 9/45] END C=0.1, weights=(0.25, 0.75, 0.0);, score=0.804 total time=   0.7s
# [CV 3/5; 9/45] END C=0.1, weights=(0.25, 0.75, 0.0);, score=0.721 total time=   0.6s
# [CV 5/5; 8/45] END C=0.1, weights=(0.25, 0.5, 0.25);, score=0.758 total time=   0.7s
# [CV 3/5; 8/45] END C=0.1, weights=(0.25, 0.5, 0.25);, score=0.771 total time=   0.8s
# [CV 1/5; 10/45] START C=0.1, weights=(0.5, 0.0, 0.5)............................
# [CV 2/5; 10/45] START C=0.1, weights=(0.5, 0.0, 0.5)............................
# [CV 2/5; 9/45] END C=0.1, weights=(0.25, 0.75, 0.0);, score=0.771 total time=   0.6s
# [CV 3/5; 10/45] START C=0.1, weights=(0.5, 0.0, 0.5)............................
# [CV 4/5; 10/45] START C=0.1, weights=(0.5, 0.0, 0.5)............................
# [CV 1/5; 10/45] END C=0.1, weights=(0.5, 0.0, 0.5);, score=0.833 total time=   0.2s
# [CV 5/5; 10/45] START C=0.1, weights=(0.5, 0.0, 0.5)............................
# [CV 2/5; 10/45] END C=0.1, weights=(0.5, 0.0, 0.5);, score=0.775 total time=   0.2s
# [CV 1/5; 11/45] START C=0.1, weights=(0.5, 0.25, 0.25)..........................
# [CV 2/5; 11/45] START C=0.1, weights=(0.5, 0.25, 0.25)..........................
# [CV 3/5; 11/45] START C=0.1, weights=(0.5, 0.25, 0.25)..........................
# [CV 4/5; 10/45] END C=0.1, weights=(0.5, 0.0, 0.5);, score=0.775 total time=   0.2s
# [CV 3/5; 10/45] END C=0.1, weights=(0.5, 0.0, 0.5);, score=0.792 total time=   0.2s
# [CV 4/5; 11/45] START C=0.1, weights=(0.5, 0.25, 0.25)..........................
# [CV 5/5; 10/45] END C=0.1, weights=(0.5, 0.0, 0.5);, score=0.758 total time=   0.2s
# [CV 5/5; 11/45] START C=0.1, weights=(0.5, 0.25, 0.25)..........................
# [CV 4/5; 9/45] END C=0.1, weights=(0.25, 0.75, 0.0);, score=0.775 total time=   0.5s
# [CV 1/5; 12/45] START C=0.1, weights=(0.5, 0.5, 0.0)............................
# [CV 1/5; 11/45] END C=0.1, weights=(0.5, 0.25, 0.25);, score=0.829 total time=   0.3s
# [CV 5/5; 9/45] END C=0.1, weights=(0.25, 0.75, 0.0);, score=0.713 total time=   0.6s
# [CV 2/5; 12/45] START C=0.1, weights=(0.5, 0.5, 0.0)............................
# [CV 3/5; 12/45] START C=0.1, weights=(0.5, 0.5, 0.0)............................
# [CV 4/5; 12/45] START C=0.1, weights=(0.5, 0.5, 0.0)............................
# [CV 2/5; 11/45] END C=0.1, weights=(0.5, 0.25, 0.25);, score=0.758 total time=   0.4s
# [CV 5/5; 12/45] START C=0.1, weights=(0.5, 0.5, 0.0)............................
# [CV 3/5; 11/45] END C=0.1, weights=(0.5, 0.25, 0.25);, score=0.783 total time=   0.5s
# [CV 1/5; 13/45] START C=0.1, weights=(0.75, 0.0, 0.25)..........................
# [CV 1/5; 13/45] END C=0.1, weights=(0.75, 0.0, 0.25);, score=0.829 total time=   0.1s
# [CV 2/5; 13/45] START C=0.1, weights=(0.75, 0.0, 0.25)..........................
# [CV 4/5; 11/45] END C=0.1, weights=(0.5, 0.25, 0.25);, score=0.787 total time=   0.6s
# [CV 3/5; 13/45] START C=0.1, weights=(0.75, 0.0, 0.25)..........................
# [CV 3/5; 12/45] END C=0.1, weights=(0.5, 0.5, 0.0);, score=0.733 total time=   0.5s
# [CV 5/5; 11/45] END C=0.1, weights=(0.5, 0.25, 0.25);, score=0.754 total time=   0.6s
# [CV 2/5; 12/45] END C=0.1, weights=(0.5, 0.5, 0.0);, score=0.779 total time=   0.5s
# [CV 1/5; 12/45] END C=0.1, weights=(0.5, 0.5, 0.0);, score=0.812 total time=   0.6s
# [CV 4/5; 13/45] START C=0.1, weights=(0.75, 0.0, 0.25)..........................
# [CV 5/5; 13/45] START C=0.1, weights=(0.75, 0.0, 0.25)..........................
# [CV 5/5; 12/45] END C=0.1, weights=(0.5, 0.5, 0.0);, score=0.713 total time=   0.4s
# [CV 1/5; 14/45] START C=0.1, weights=(0.75, 0.25, 0.0)..........................
# [CV 2/5; 14/45] START C=0.1, weights=(0.75, 0.25, 0.0)..........................
# [CV 3/5; 14/45] START C=0.1, weights=(0.75, 0.25, 0.0)..........................
# [CV 4/5; 12/45] END C=0.1, weights=(0.5, 0.5, 0.0);, score=0.796 total time=   0.6s
# [CV 4/5; 13/45] END C=0.1, weights=(0.75, 0.0, 0.25);, score=0.787 total time=   0.2s
# [CV 4/5; 14/45] START C=0.1, weights=(0.75, 0.25, 0.0)..........................
# [CV 5/5; 13/45] END C=0.1, weights=(0.75, 0.0, 0.25);, score=0.762 total time=   0.2s
# [CV 2/5; 13/45] END C=0.1, weights=(0.75, 0.0, 0.25);, score=0.775 total time=   0.3s
# [CV 3/5; 13/45] END C=0.1, weights=(0.75, 0.0, 0.25);, score=0.787 total time=   0.3s
# [CV 1/5; 14/45] END C=0.1, weights=(0.75, 0.25, 0.0);, score=0.808 total time=   0.2s
# [CV 5/5; 14/45] START C=0.1, weights=(0.75, 0.25, 0.0)..........................
# [CV 1/5; 15/45] START C=0.1, weights=(1.0, 0.0, 0.0)............................
# [CV 2/5; 15/45] START C=0.1, weights=(1.0, 0.0, 0.0)............................
# [CV 2/5; 14/45] END C=0.1, weights=(0.75, 0.25, 0.0);, score=0.783 total time=   0.4s
# [CV 3/5; 15/45] START C=0.1, weights=(1.0, 0.0, 0.0)............................
# [CV 1/5; 15/45] END C=0.1, weights=(1.0, 0.0, 0.0);, score=0.787 total time=   0.1s
# [CV 3/5; 14/45] END C=0.1, weights=(0.75, 0.25, 0.0);, score=0.742 total time=   0.3s
# [CV 4/5; 15/45] START C=0.1, weights=(1.0, 0.0, 0.0)............................
# [CV 4/5; 14/45] END C=0.1, weights=(0.75, 0.25, 0.0);, score=0.800 total time=   0.3s
# [CV 2/5; 15/45] END C=0.1, weights=(1.0, 0.0, 0.0);, score=0.738 total time=   0.1s
# [CV 3/5; 15/45] END C=0.1, weights=(1.0, 0.0, 0.0);, score=0.729 total time=   0.1s
# [CV 5/5; 15/45] START C=0.1, weights=(1.0, 0.0, 0.0)............................
# [CV 4/5; 15/45] END C=0.1, weights=(1.0, 0.0, 0.0);, score=0.742 total time=   0.0s
# [CV 1/5; 16/45] START C=0.5, weights=(0.0, 0.0, 1.0)............................
# [CV 5/5; 15/45] END C=0.1, weights=(1.0, 0.0, 0.0);, score=0.742 total time=   0.1s
# [CV 2/5; 16/45] START C=0.5, weights=(0.0, 0.0, 1.0)............................
# [CV 5/5; 14/45] END C=0.1, weights=(0.75, 0.25, 0.0);, score=0.713 total time=   0.3s
# [CV 3/5; 16/45] START C=0.5, weights=(0.0, 0.0, 1.0)............................
# [CV 4/5; 16/45] START C=0.5, weights=(0.0, 0.0, 1.0)............................
# [CV 5/5; 16/45] START C=0.5, weights=(0.0, 0.0, 1.0)............................
# [CV 1/5; 17/45] START C=0.5, weights=(0.0, 0.25, 0.75)..........................
# [CV 2/5; 17/45] START C=0.5, weights=(0.0, 0.25, 0.75)..........................
# [CV 3/5; 17/45] START C=0.5, weights=(0.0, 0.25, 0.75)..........................
# [CV 2/5; 16/45] END C=0.5, weights=(0.0, 0.0, 1.0);, score=0.725 total time=   1.7s
# [CV 5/5; 16/45] END C=0.5, weights=(0.0, 0.0, 1.0);, score=0.692 total time=   1.6s
# [CV 5/5; 17/45] START C=0.5, weights=(0.0, 0.25, 0.75)..........................
# [CV 4/5; 17/45] START C=0.5, weights=(0.0, 0.25, 0.75)..........................
# [CV 3/5; 16/45] END C=0.5, weights=(0.0, 0.0, 1.0);, score=0.696 total time=   2.1s
# [CV 1/5; 18/45] START C=0.5, weights=(0.0, 0.5, 0.5)............................
# [CV 1/5; 17/45] END C=0.5, weights=(0.0, 0.25, 0.75);, score=0.796 total time=   2.2s
# [CV 2/5; 18/45] START C=0.5, weights=(0.0, 0.5, 0.5)............................
# [CV 3/5; 17/45] END C=0.5, weights=(0.0, 0.25, 0.75);, score=0.750 total time=   2.3s
# [CV 1/5; 16/45] END C=0.5, weights=(0.0, 0.0, 1.0);, score=0.758 total time=   2.6s
# [CV 3/5; 18/45] START C=0.5, weights=(0.0, 0.5, 0.5)............................
# [CV 2/5; 17/45] END C=0.5, weights=(0.0, 0.25, 0.75);, score=0.762 total time=   2.4s
# [CV 4/5; 18/45] START C=0.5, weights=(0.0, 0.5, 0.5)............................
# [CV 5/5; 18/45] START C=0.5, weights=(0.0, 0.5, 0.5)............................
# [CV 4/5; 16/45] END C=0.5, weights=(0.0, 0.0, 1.0);, score=0.767 total time=   2.7s
# [CV 1/5; 19/45] START C=0.5, weights=(0.0, 0.75, 0.25)..........................
# [CV 5/5; 17/45] END C=0.5, weights=(0.0, 0.25, 0.75);, score=0.688 total time=   2.6s
# [CV 2/5; 19/45] START C=0.5, weights=(0.0, 0.75, 0.25)..........................
# [CV 4/5; 17/45] END C=0.5, weights=(0.0, 0.25, 0.75);, score=0.733 total time=   3.0s
# [CV 3/5; 19/45] START C=0.5, weights=(0.0, 0.75, 0.25)..........................
# [CV 1/5; 18/45] END C=0.5, weights=(0.0, 0.5, 0.5);, score=0.779 total time=   2.7s
# [CV 4/5; 19/45] START C=0.5, weights=(0.0, 0.75, 0.25)..........................
# [CV 3/5; 18/45] END C=0.5, weights=(0.0, 0.5, 0.5);, score=0.754 total time=   4.3s
# [CV 5/5; 19/45] START C=0.5, weights=(0.0, 0.75, 0.25)..........................
# [CV 4/5; 18/45] END C=0.5, weights=(0.0, 0.5, 0.5);, score=0.750 total time=   4.6s
# [CV 1/5; 20/45] START C=0.5, weights=(0.0, 1.0, 0.0)............................
# [CV 2/5; 18/45] END C=0.5, weights=(0.0, 0.5, 0.5);, score=0.783 total time=   5.4s
# [CV 2/5; 20/45] START C=0.5, weights=(0.0, 1.0, 0.0)............................
# [CV 5/5; 18/45] END C=0.5, weights=(0.0, 0.5, 0.5);, score=0.692 total time=   5.9s
# [CV 3/5; 20/45] START C=0.5, weights=(0.0, 1.0, 0.0)............................
# [CV 1/5; 19/45] END C=0.5, weights=(0.0, 0.75, 0.25);, score=0.762 total time=   6.8s
# [CV 4/5; 20/45] START C=0.5, weights=(0.0, 1.0, 0.0)............................
# [CV 3/5; 19/45] END C=0.5, weights=(0.0, 0.75, 0.25);, score=0.746 total time=   6.5s
# [CV 5/5; 20/45] START C=0.5, weights=(0.0, 1.0, 0.0)............................
# [CV 2/5; 19/45] END C=0.5, weights=(0.0, 0.75, 0.25);, score=0.783 total time=   8.0s
# [CV 1/5; 21/45] START C=0.5, weights=(0.25, 0.0, 0.75)..........................
# [CV 5/5; 19/45] END C=0.5, weights=(0.0, 0.75, 0.25);, score=0.696 total time=   5.6s
# [CV 2/5; 21/45] START C=0.5, weights=(0.25, 0.0, 0.75)..........................
# [CV 1/5; 21/45] END C=0.5, weights=(0.25, 0.0, 0.75);, score=0.842 total time=   1.0s
# [CV 3/5; 21/45] START C=0.5, weights=(0.25, 0.0, 0.75)..........................
# [CV 2/5; 21/45] END C=0.5, weights=(0.25, 0.0, 0.75);, score=0.783 total time=   0.8s
# [CV 4/5; 21/45] START C=0.5, weights=(0.25, 0.0, 0.75)..........................
# [CV 4/5; 19/45] END C=0.5, weights=(0.0, 0.75, 0.25);, score=0.742 total time=   9.0s
# [CV 5/5; 21/45] START C=0.5, weights=(0.25, 0.0, 0.75)..........................
# [CV 3/5; 21/45] END C=0.5, weights=(0.25, 0.0, 0.75);, score=0.796 total time=   0.8s
# [CV 1/5; 22/45] START C=0.5, weights=(0.25, 0.25, 0.5)..........................
# [CV 4/5; 21/45] END C=0.5, weights=(0.25, 0.0, 0.75);, score=0.779 total time=   1.5s
# [CV 2/5; 22/45] START C=0.5, weights=(0.25, 0.25, 0.5)..........................
# [CV 1/5; 20/45] END C=0.5, weights=(0.0, 1.0, 0.0);, score=0.775 total time=   8.8s
# [CV 3/5; 22/45] START C=0.5, weights=(0.25, 0.25, 0.5)..........................
# [CV 5/5; 21/45] END C=0.5, weights=(0.25, 0.0, 0.75);, score=0.762 total time=   2.3s
# [CV 4/5; 22/45] START C=0.5, weights=(0.25, 0.25, 0.5)..........................
# [CV 1/5; 22/45] END C=0.5, weights=(0.25, 0.25, 0.5);, score=0.838 total time=   3.1s
# [CV 5/5; 22/45] START C=0.5, weights=(0.25, 0.25, 0.5)..........................
# [CV 3/5; 20/45] END C=0.5, weights=(0.0, 1.0, 0.0);, score=0.692 total time=   8.8s
# [CV 1/5; 23/45] START C=0.5, weights=(0.25, 0.5, 0.25)..........................
# [CV 2/5; 20/45] END C=0.5, weights=(0.0, 1.0, 0.0);, score=0.800 total time=   9.9s
# [CV 2/5; 23/45] START C=0.5, weights=(0.25, 0.5, 0.25)..........................
# [CV 4/5; 20/45] END C=0.5, weights=(0.0, 1.0, 0.0);, score=0.746 total time=   8.3s
# [CV 3/5; 23/45] START C=0.5, weights=(0.25, 0.5, 0.25)..........................
# [CV 2/5; 22/45] END C=0.5, weights=(0.25, 0.25, 0.5);, score=0.762 total time=   3.4s
# [CV 4/5; 23/45] START C=0.5, weights=(0.25, 0.5, 0.25)..........................
# [CV 4/5; 22/45] END C=0.5, weights=(0.25, 0.25, 0.5);, score=0.783 total time=   2.1s
# [CV 5/5; 23/45] START C=0.5, weights=(0.25, 0.5, 0.25)..........................
# [CV 3/5; 22/45] END C=0.5, weights=(0.25, 0.25, 0.5);, score=0.783 total time=   2.7s
# [CV 1/5; 24/45] START C=0.5, weights=(0.25, 0.75, 0.0)..........................
# [CV 5/5; 20/45] END C=0.5, weights=(0.0, 1.0, 0.0);, score=0.704 total time=   7.8s
# [CV 2/5; 24/45] START C=0.5, weights=(0.25, 0.75, 0.0)..........................
# [CV 5/5; 22/45] END C=0.5, weights=(0.25, 0.25, 0.5);, score=0.767 total time=   2.0s
# [CV 3/5; 24/45] START C=0.5, weights=(0.25, 0.75, 0.0)..........................
# [CV 3/5; 23/45] END C=0.5, weights=(0.25, 0.5, 0.25);, score=0.779 total time=   3.0s
# [CV 4/5; 23/45] END C=0.5, weights=(0.25, 0.5, 0.25);, score=0.787 total time=   2.7s
# [CV 4/5; 24/45] START C=0.5, weights=(0.25, 0.75, 0.0)..........................
# [CV 1/5; 23/45] END C=0.5, weights=(0.25, 0.5, 0.25);, score=0.833 total time=   3.7s
# [CV 5/5; 24/45] START C=0.5, weights=(0.25, 0.75, 0.0)..........................
# [CV 1/5; 25/45] START C=0.5, weights=(0.5, 0.0, 0.5)............................
# [CV 2/5; 23/45] END C=0.5, weights=(0.25, 0.5, 0.25);, score=0.779 total time=   3.6s
# [CV 2/5; 25/45] START C=0.5, weights=(0.5, 0.0, 0.5)............................
# [CV 1/5; 25/45] END C=0.5, weights=(0.5, 0.0, 0.5);, score=0.850 total time=   0.4s
# [CV 3/5; 25/45] START C=0.5, weights=(0.5, 0.0, 0.5)............................
# [CV 5/5; 23/45] END C=0.5, weights=(0.25, 0.5, 0.25);, score=0.779 total time=   3.5s
# [CV 4/5; 25/45] START C=0.5, weights=(0.5, 0.0, 0.5)............................
# [CV 3/5; 25/45] END C=0.5, weights=(0.5, 0.0, 0.5);, score=0.787 total time=   0.5s
# [CV 2/5; 25/45] END C=0.5, weights=(0.5, 0.0, 0.5);, score=0.783 total time=   0.6s
# [CV 5/5; 25/45] START C=0.5, weights=(0.5, 0.0, 0.5)............................
# [CV 1/5; 24/45] END C=0.5, weights=(0.25, 0.75, 0.0);, score=0.792 total time=   3.2s
# [CV 1/5; 26/45] START C=0.5, weights=(0.5, 0.25, 0.25)..........................
# [CV 2/5; 26/45] START C=0.5, weights=(0.5, 0.25, 0.25)..........................
# [CV 4/5; 25/45] END C=0.5, weights=(0.5, 0.0, 0.5);, score=0.779 total time=   0.8s
# [CV 5/5; 25/45] END C=0.5, weights=(0.5, 0.0, 0.5);, score=0.767 total time=   0.8s
# [CV 4/5; 26/45] START C=0.5, weights=(0.5, 0.25, 0.25)..........................
# [CV 3/5; 26/45] START C=0.5, weights=(0.5, 0.25, 0.25)..........................
# [CV 1/5; 26/45] END C=0.5, weights=(0.5, 0.25, 0.25);, score=0.829 total time=   1.4s
# [CV 5/5; 26/45] START C=0.5, weights=(0.5, 0.25, 0.25)..........................
# [CV 2/5; 24/45] END C=0.5, weights=(0.25, 0.75, 0.0);, score=0.783 total time=   4.4s
# [CV 1/5; 27/45] START C=0.5, weights=(0.5, 0.5, 0.0)............................
# [CV 4/5; 24/45] END C=0.5, weights=(0.25, 0.75, 0.0);, score=0.771 total time=   2.6s
# [CV 2/5; 27/45] START C=0.5, weights=(0.5, 0.5, 0.0)............................
# [CV 2/5; 26/45] END C=0.5, weights=(0.5, 0.25, 0.25);, score=0.771 total time=   1.9s
# [CV 5/5; 24/45] END C=0.5, weights=(0.25, 0.75, 0.0);, score=0.742 total time=   2.9s
# [CV 3/5; 27/45] START C=0.5, weights=(0.5, 0.5, 0.0)............................
# [CV 4/5; 27/45] START C=0.5, weights=(0.5, 0.5, 0.0)............................
# [CV 3/5; 24/45] END C=0.5, weights=(0.25, 0.75, 0.0);, score=0.713 total time=   4.9s
# [CV 5/5; 27/45] START C=0.5, weights=(0.5, 0.5, 0.0)............................
# [CV 3/5; 26/45] END C=0.5, weights=(0.5, 0.25, 0.25);, score=0.787 total time=   1.5s
# [CV 1/5; 28/45] START C=0.5, weights=(0.75, 0.0, 0.25)..........................
# [CV 4/5; 26/45] END C=0.5, weights=(0.5, 0.25, 0.25);, score=0.783 total time=   1.7s
# [CV 2/5; 28/45] START C=0.5, weights=(0.75, 0.0, 0.25)..........................
# [CV 1/5; 28/45] END C=0.5, weights=(0.75, 0.0, 0.25);, score=0.854 total time=   0.5s
# [CV 3/5; 28/45] START C=0.5, weights=(0.75, 0.0, 0.25)..........................
# [CV 2/5; 28/45] END C=0.5, weights=(0.75, 0.0, 0.25);, score=0.787 total time=   0.4s
# [CV 4/5; 28/45] START C=0.5, weights=(0.75, 0.0, 0.25)..........................
# [CV 3/5; 28/45] END C=0.5, weights=(0.75, 0.0, 0.25);, score=0.787 total time=   0.3s
# [CV 5/5; 28/45] START C=0.5, weights=(0.75, 0.0, 0.25)..........................
# [CV 4/5; 28/45] END C=0.5, weights=(0.75, 0.0, 0.25);, score=0.779 total time=   0.7s
# [CV 1/5; 29/45] START C=0.5, weights=(0.75, 0.25, 0.0)..........................
# [CV 5/5; 26/45] END C=0.5, weights=(0.5, 0.25, 0.25);, score=0.771 total time=   2.3s
# [CV 5/5; 28/45] END C=0.5, weights=(0.75, 0.0, 0.25);, score=0.779 total time=   0.6s
# [CV 3/5; 29/45] START C=0.5, weights=(0.75, 0.25, 0.0)..........................
# [CV 2/5; 29/45] START C=0.5, weights=(0.75, 0.25, 0.0)..........................
# [CV 5/5; 27/45] END C=0.5, weights=(0.5, 0.5, 0.0);, score=0.733 total time=   2.6s
# [CV 4/5; 29/45] START C=0.5, weights=(0.75, 0.25, 0.0)..........................
# [CV 4/5; 27/45] END C=0.5, weights=(0.5, 0.5, 0.0);, score=0.787 total time=   2.8s
# [CV 5/5; 29/45] START C=0.5, weights=(0.75, 0.25, 0.0)..........................
# [CV 2/5; 27/45] END C=0.5, weights=(0.5, 0.5, 0.0);, score=0.771 total time=   3.5s
# [CV 1/5; 30/45] START C=0.5, weights=(1.0, 0.0, 0.0)............................
# [CV 1/5; 27/45] END C=0.5, weights=(0.5, 0.5, 0.0);, score=0.796 total time=   3.6s
# [CV 2/5; 30/45] START C=0.5, weights=(1.0, 0.0, 0.0)............................
# [CV 1/5; 29/45] END C=0.5, weights=(0.75, 0.25, 0.0);, score=0.808 total time=   1.6s
# [CV 3/5; 30/45] START C=0.5, weights=(1.0, 0.0, 0.0)............................
# [CV 3/5; 30/45] END C=0.5, weights=(1.0, 0.0, 0.0);, score=0.750 total time=   0.1s
# [CV 4/5; 30/45] START C=0.5, weights=(1.0, 0.0, 0.0)............................
# [CV 2/5; 30/45] END C=0.5, weights=(1.0, 0.0, 0.0);, score=0.750 total time=   0.2s
# [CV 5/5; 30/45] START C=0.5, weights=(1.0, 0.0, 0.0)............................
# [CV 4/5; 30/45] END C=0.5, weights=(1.0, 0.0, 0.0);, score=0.750 total time=   0.1s
# [CV 1/5; 30/45] END C=0.5, weights=(1.0, 0.0, 0.0);, score=0.792 total time=   0.3s
# [CV 5/5; 30/45] END C=0.5, weights=(1.0, 0.0, 0.0);, score=0.754 total time=   0.1s
# [CV 3/5; 27/45] END C=0.5, weights=(0.5, 0.5, 0.0);, score=0.717 total time=   3.5s
# [CV 2/5; 31/45] START C=1.0, weights=(0.0, 0.0, 1.0)............................
# [CV 3/5; 31/45] START C=1.0, weights=(0.0, 0.0, 1.0)............................
# [CV 1/5; 31/45] START C=1.0, weights=(0.0, 0.0, 1.0)............................
# [CV 4/5; 31/45] START C=1.0, weights=(0.0, 0.0, 1.0)............................
# [CV 4/5; 29/45] END C=0.5, weights=(0.75, 0.25, 0.0);, score=0.792 total time=   1.0s
# [CV 5/5; 31/45] START C=1.0, weights=(0.0, 0.0, 1.0)............................
# [CV 2/5; 29/45] END C=0.5, weights=(0.75, 0.25, 0.0);, score=0.779 total time=   1.8s
# [CV 1/5; 32/45] START C=1.0, weights=(0.0, 0.25, 0.75)..........................
# [CV 5/5; 29/45] END C=0.5, weights=(0.75, 0.25, 0.0);, score=0.725 total time=   0.9s
# [CV 3/5; 29/45] END C=0.5, weights=(0.75, 0.25, 0.0);, score=0.729 total time=   1.9s
# [CV 2/5; 32/45] START C=1.0, weights=(0.0, 0.25, 0.75)..........................
# [CV 3/5; 32/45] START C=1.0, weights=(0.0, 0.25, 0.75)..........................
# [CV 5/5; 31/45] END C=1.0, weights=(0.0, 0.0, 1.0);, score=0.696 total time=   3.2s
# [CV 4/5; 32/45] START C=1.0, weights=(0.0, 0.25, 0.75)..........................
# [CV 4/5; 31/45] END C=1.0, weights=(0.0, 0.0, 1.0);, score=0.762 total time=   4.1s
# [CV 5/5; 32/45] START C=1.0, weights=(0.0, 0.25, 0.75)..........................
# [CV 2/5; 31/45] END C=1.0, weights=(0.0, 0.0, 1.0);, score=0.733 total time=   4.3s
# [CV 1/5; 33/45] START C=1.0, weights=(0.0, 0.5, 0.5)............................
# [CV 1/5; 31/45] END C=1.0, weights=(0.0, 0.0, 1.0);, score=0.767 total time=   4.8s
# [CV 2/5; 33/45] START C=1.0, weights=(0.0, 0.5, 0.5)............................
# [CV 1/5; 32/45] END C=1.0, weights=(0.0, 0.25, 0.75);, score=0.783 total time=   5.3s
# [CV 3/5; 33/45] START C=1.0, weights=(0.0, 0.5, 0.5)............................
# [CV 3/5; 31/45] END C=1.0, weights=(0.0, 0.0, 1.0);, score=0.704 total time=   6.1s
# [CV 4/5; 33/45] START C=1.0, weights=(0.0, 0.5, 0.5)............................
# [CV 2/5; 32/45] END C=1.0, weights=(0.0, 0.25, 0.75);, score=0.779 total time=   7.0s
# [CV 5/5; 33/45] START C=1.0, weights=(0.0, 0.5, 0.5)............................
# [CV 3/5; 32/45] END C=1.0, weights=(0.0, 0.25, 0.75);, score=0.754 total time=   7.4s
# [CV 1/5; 34/45] START C=1.0, weights=(0.0, 0.75, 0.25)..........................
# [CV 4/5; 32/45] END C=1.0, weights=(0.0, 0.25, 0.75);, score=0.746 total time=   5.7s
# [CV 2/5; 34/45] START C=1.0, weights=(0.0, 0.75, 0.25)..........................
# [CV 5/5; 32/45] END C=1.0, weights=(0.0, 0.25, 0.75);, score=0.696 total time=   6.1s
# [CV 3/5; 34/45] START C=1.0, weights=(0.0, 0.75, 0.25)..........................
# [CV 1/5; 33/45] END C=1.0, weights=(0.0, 0.5, 0.5);, score=0.771 total time=   9.0s
# [CV 4/5; 34/45] START C=1.0, weights=(0.0, 0.75, 0.25)..........................
# [CV 3/5; 33/45] END C=1.0, weights=(0.0, 0.5, 0.5);, score=0.746 total time=  10.0s
# [CV 5/5; 34/45] START C=1.0, weights=(0.0, 0.75, 0.25)..........................
# [CV 4/5; 33/45] END C=1.0, weights=(0.0, 0.5, 0.5);, score=0.746 total time=  10.0s
# [CV 2/5; 33/45] END C=1.0, weights=(0.0, 0.5, 0.5);, score=0.771 total time=  11.1s
# [CV 1/5; 35/45] START C=1.0, weights=(0.0, 1.0, 0.0)............................
# [CV 2/5; 35/45] START C=1.0, weights=(0.0, 1.0, 0.0)............................
# [CV 5/5; 33/45] END C=1.0, weights=(0.0, 0.5, 0.5);, score=0.713 total time=  11.9s
# [CV 3/5; 35/45] START C=1.0, weights=(0.0, 1.0, 0.0)............................
# [CV 1/5; 34/45] END C=1.0, weights=(0.0, 0.75, 0.25);, score=0.767 total time=  15.7s
# [CV 4/5; 35/45] START C=1.0, weights=(0.0, 1.0, 0.0)............................
# [CV 2/5; 34/45] END C=1.0, weights=(0.0, 0.75, 0.25);, score=0.767 total time=  14.7s
# [CV 5/5; 35/45] START C=1.0, weights=(0.0, 1.0, 0.0)............................
# [CV 3/5; 34/45] END C=1.0, weights=(0.0, 0.75, 0.25);, score=0.738 total time=  15.6s
# [CV 1/5; 36/45] START C=1.0, weights=(0.25, 0.0, 0.75)..........................
# [CV 1/5; 36/45] END C=1.0, weights=(0.25, 0.0, 0.75);, score=0.842 total time=   2.0s
# [CV 2/5; 36/45] START C=1.0, weights=(0.25, 0.0, 0.75)..........................
# [CV 4/5; 34/45] END C=1.0, weights=(0.0, 0.75, 0.25);, score=0.754 total time=  15.0s
# [CV 3/5; 36/45] START C=1.0, weights=(0.25, 0.0, 0.75)..........................
# [CV 5/5; 34/45] END C=1.0, weights=(0.0, 0.75, 0.25);, score=0.733 total time=  14.1s
# [CV 4/5; 36/45] START C=1.0, weights=(0.25, 0.0, 0.75)..........................
# [CV 2/5; 36/45] END C=1.0, weights=(0.25, 0.0, 0.75);, score=0.771 total time=   2.5s
# [CV 5/5; 36/45] START C=1.0, weights=(0.25, 0.0, 0.75)..........................
# [CV 3/5; 36/45] END C=1.0, weights=(0.25, 0.0, 0.75);, score=0.796 total time=   2.7s
# [CV 1/5; 37/45] START C=1.0, weights=(0.25, 0.25, 0.5)..........................
# [CV 5/5; 36/45] END C=1.0, weights=(0.25, 0.0, 0.75);, score=0.771 total time=   1.9s
# [CV 2/5; 37/45] START C=1.0, weights=(0.25, 0.25, 0.5)..........................
# [CV 4/5; 36/45] END C=1.0, weights=(0.25, 0.0, 0.75);, score=0.779 total time=   3.4s
# [CV 3/5; 37/45] START C=1.0, weights=(0.25, 0.25, 0.5)..........................
# [CV 1/5; 35/45] END C=1.0, weights=(0.0, 1.0, 0.0);, score=0.771 total time=  19.8s
# [CV 4/5; 37/45] START C=1.0, weights=(0.25, 0.25, 0.5)..........................
# [CV 1/5; 37/45] END C=1.0, weights=(0.25, 0.25, 0.5);, score=0.829 total time=   5.7s
# [CV 5/5; 37/45] START C=1.0, weights=(0.25, 0.25, 0.5)..........................
# [CV 2/5; 37/45] END C=1.0, weights=(0.25, 0.25, 0.5);, score=0.767 total time=   5.3s
# [CV 1/5; 38/45] START C=1.0, weights=(0.25, 0.5, 0.25)..........................
# [CV 3/5; 35/45] END C=1.0, weights=(0.0, 1.0, 0.0);, score=0.692 total time=  19.8s
# [CV 2/5; 38/45] START C=1.0, weights=(0.25, 0.5, 0.25)..........................
# [CV 3/5; 37/45] END C=1.0, weights=(0.25, 0.25, 0.5);, score=0.787 total time=   6.4s
# [CV 3/5; 38/45] START C=1.0, weights=(0.25, 0.5, 0.25)..........................
# [CV 5/5; 35/45] END C=1.0, weights=(0.0, 1.0, 0.0);, score=0.696 total time=  16.5s
# [CV 4/5; 38/45] START C=1.0, weights=(0.25, 0.5, 0.25)..........................
# [CV 5/5; 37/45] END C=1.0, weights=(0.25, 0.25, 0.5);, score=0.775 total time=   7.8s
# [CV 5/5; 38/45] START C=1.0, weights=(0.25, 0.5, 0.25)..........................
# [CV 4/5; 37/45] END C=1.0, weights=(0.25, 0.25, 0.5);, score=0.783 total time=   8.9s
# [CV 1/5; 39/45] START C=1.0, weights=(0.25, 0.75, 0.0)..........................
# [CV 2/5; 35/45] END C=1.0, weights=(0.0, 1.0, 0.0);, score=0.800 total time=  29.6s
# [CV 2/5; 39/45] START C=1.0, weights=(0.25, 0.75, 0.0)..........................
# [CV 1/5; 38/45] END C=1.0, weights=(0.25, 0.5, 0.25);, score=0.825 total time=  10.4s
# [CV 3/5; 39/45] START C=1.0, weights=(0.25, 0.75, 0.0)..........................
# [CV 3/5; 38/45] END C=1.0, weights=(0.25, 0.5, 0.25);, score=0.779 total time=   8.8s
# [CV 4/5; 39/45] START C=1.0, weights=(0.25, 0.75, 0.0)..........................
# [CV 2/5; 38/45] END C=1.0, weights=(0.25, 0.5, 0.25);, score=0.767 total time=   9.4s
# [CV 5/5; 39/45] START C=1.0, weights=(0.25, 0.75, 0.0)..........................
# [CV 4/5; 35/45] END C=1.0, weights=(0.0, 1.0, 0.0);, score=0.738 total time=  25.8s
# [CV 1/5; 40/45] START C=1.0, weights=(0.5, 0.0, 0.5)............................
# [CV 4/5; 38/45] END C=1.0, weights=(0.25, 0.5, 0.25);, score=0.787 total time=   9.8s
# [CV 2/5; 40/45] START C=1.0, weights=(0.5, 0.0, 0.5)............................
# [CV 1/5; 40/45] END C=1.0, weights=(0.5, 0.0, 0.5);, score=0.842 total time=   1.5s
# [CV 3/5; 40/45] START C=1.0, weights=(0.5, 0.0, 0.5)............................
# [CV 2/5; 40/45] END C=1.0, weights=(0.5, 0.0, 0.5);, score=0.779 total time=   1.2s
# [CV 4/5; 40/45] START C=1.0, weights=(0.5, 0.0, 0.5)............................
# [CV 3/5; 40/45] END C=1.0, weights=(0.5, 0.0, 0.5);, score=0.792 total time=   1.3s
# [CV 5/5; 40/45] START C=1.0, weights=(0.5, 0.0, 0.5)............................
# [CV 5/5; 38/45] END C=1.0, weights=(0.25, 0.5, 0.25);, score=0.783 total time=   7.5s
# [CV 1/5; 41/45] START C=1.0, weights=(0.5, 0.25, 0.25)..........................
# [CV 4/5; 40/45] END C=1.0, weights=(0.5, 0.0, 0.5);, score=0.779 total time=   1.6s
# [CV 2/5; 41/45] START C=1.0, weights=(0.5, 0.25, 0.25)..........................
# [CV 5/5; 40/45] END C=1.0, weights=(0.5, 0.0, 0.5);, score=0.771 total time=   1.2s
# [CV 3/5; 41/45] START C=1.0, weights=(0.5, 0.25, 0.25)..........................
# [CV 4/5; 39/45] END C=1.0, weights=(0.25, 0.75, 0.0);, score=0.762 total time=   7.4s
# [CV 4/5; 41/45] START C=1.0, weights=(0.5, 0.25, 0.25)..........................
# [CV 3/5; 41/45] END C=1.0, weights=(0.5, 0.25, 0.25);, score=0.787 total time=   4.0s
# [CV 5/5; 41/45] START C=1.0, weights=(0.5, 0.25, 0.25)..........................
# [CV 1/5; 41/45] END C=1.0, weights=(0.5, 0.25, 0.25);, score=0.829 total time=   5.2s
# [CV 1/5; 42/45] START C=1.0, weights=(0.5, 0.5, 0.0)............................
# [CV 2/5; 41/45] END C=1.0, weights=(0.5, 0.25, 0.25);, score=0.771 total time=   4.3s
# [CV 2/5; 42/45] START C=1.0, weights=(0.5, 0.5, 0.0)............................
# [CV 1/5; 39/45] END C=1.0, weights=(0.25, 0.75, 0.0);, score=0.783 total time=  12.8s
# [CV 3/5; 42/45] START C=1.0, weights=(0.5, 0.5, 0.0)............................
# [CV 2/5; 39/45] END C=1.0, weights=(0.25, 0.75, 0.0);, score=0.771 total time=  12.6s
# [CV 4/5; 42/45] START C=1.0, weights=(0.5, 0.5, 0.0)............................
# [CV 3/5; 39/45] END C=1.0, weights=(0.25, 0.75, 0.0);, score=0.713 total time=  10.6s
# [CV 5/5; 42/45] START C=1.0, weights=(0.5, 0.5, 0.0)............................
# [CV 5/5; 39/45] END C=1.0, weights=(0.25, 0.75, 0.0);, score=0.721 total time=  10.5s
# [CV 1/5; 43/45] START C=1.0, weights=(0.75, 0.0, 0.25)..........................
# [CV 4/5; 41/45] END C=1.0, weights=(0.5, 0.25, 0.25);, score=0.779 total time=   4.0s
# [CV 2/5; 43/45] START C=1.0, weights=(0.75, 0.0, 0.25)..........................
# [CV 1/5; 43/45] END C=1.0, weights=(0.75, 0.0, 0.25);, score=0.850 total time=   1.2s
# [CV 3/5; 43/45] START C=1.0, weights=(0.75, 0.0, 0.25)..........................
# [CV 2/5; 43/45] END C=1.0, weights=(0.75, 0.0, 0.25);, score=0.775 total time=   0.8s
# [CV 4/5; 43/45] START C=1.0, weights=(0.75, 0.0, 0.25)..........................
# [CV 3/5; 43/45] END C=1.0, weights=(0.75, 0.0, 0.25);, score=0.775 total time=   0.9s
# [CV 5/5; 43/45] START C=1.0, weights=(0.75, 0.0, 0.25)..........................
# [CV 4/5; 43/45] END C=1.0, weights=(0.75, 0.0, 0.25);, score=0.779 total time=   1.1s
# [CV 1/5; 44/45] START C=1.0, weights=(0.75, 0.25, 0.0)..........................
# [CV 5/5; 43/45] END C=1.0, weights=(0.75, 0.0, 0.25);, score=0.775 total time=   0.8s
# [CV 2/5; 44/45] START C=1.0, weights=(0.75, 0.25, 0.0)..........................
# [CV 5/5; 41/45] END C=1.0, weights=(0.5, 0.25, 0.25);, score=0.775 total time=   5.1s
# [CV 3/5; 44/45] START C=1.0, weights=(0.75, 0.25, 0.0)..........................
# [CV 1/5; 42/45] END C=1.0, weights=(0.5, 0.5, 0.0);, score=0.792 total time=   6.6s
# [CV 4/5; 44/45] START C=1.0, weights=(0.75, 0.25, 0.0)..........................
# [CV 3/5; 42/45] END C=1.0, weights=(0.5, 0.5, 0.0);, score=0.729 total time=   6.5s
# [CV 5/5; 44/45] START C=1.0, weights=(0.75, 0.25, 0.0)..........................
# [CV 1/5; 44/45] END C=1.0, weights=(0.75, 0.25, 0.0);, score=0.792 total time=   2.9s
# [CV 1/5; 45/45] START C=1.0, weights=(1.0, 0.0, 0.0)............................
# [CV 1/5; 45/45] END C=1.0, weights=(1.0, 0.0, 0.0);, score=0.796 total time=   0.2s
# [CV 2/5; 45/45] START C=1.0, weights=(1.0, 0.0, 0.0)............................
# [CV 2/5; 45/45] END C=1.0, weights=(1.0, 0.0, 0.0);, score=0.746 total time=   0.2s
# [CV 3/5; 45/45] START C=1.0, weights=(1.0, 0.0, 0.0)............................
# [CV 3/5; 45/45] END C=1.0, weights=(1.0, 0.0, 0.0);, score=0.746 total time=   0.1s
# [CV 4/5; 45/45] START C=1.0, weights=(1.0, 0.0, 0.0)............................
# [CV 4/5; 45/45] END C=1.0, weights=(1.0, 0.0, 0.0);, score=0.762 total time=   0.1s
# [CV 5/5; 45/45] START C=1.0, weights=(1.0, 0.0, 0.0)............................
# [CV 5/5; 45/45] END C=1.0, weights=(1.0, 0.0, 0.0);, score=0.721 total time=   0.1s
# [CV 5/5; 42/45] END C=1.0, weights=(0.5, 0.5, 0.0);, score=0.733 total time=   6.5s
# [CV 2/5; 44/45] END C=1.0, weights=(0.75, 0.25, 0.0);, score=0.771 total time=   3.3s
# [CV 4/5; 42/45] END C=1.0, weights=(0.5, 0.5, 0.0);, score=0.775 total time=   7.2s
# [CV 4/5; 44/45] END C=1.0, weights=(0.75, 0.25, 0.0);, score=0.792 total time=   1.8s
# [CV 3/5; 44/45] END C=1.0, weights=(0.75, 0.25, 0.0);, score=0.725 total time=   3.3s
# [CV 5/5; 44/45] END C=1.0, weights=(0.75, 0.25, 0.0);, score=0.738 total time=   1.9s
# [CV 2/5; 42/45] END C=1.0, weights=(0.5, 0.5, 0.0);, score=0.775 total time=   8.6s
# Best params: {'C': 0.5, 'weights': (0.75, 0.0, 0.25)}
# Best CV accuracy: 0.7975
#
# Test accuracy: 0.8050
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81       200
#            1       0.81      0.80      0.80       200
#
#     accuracy                           0.81       400
#    macro avg       0.81      0.80      0.80       400
# weighted avg       0.81      0.81      0.80       400
#
# Confusion matrix:
# [[163  37]
#  [ 41 159]]
